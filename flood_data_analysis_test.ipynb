# %% [markdown]
# # 🧮 Flood Events Data Analysis Test
# This notebook is a technical assessment designed to evaluate your skills in pandas-based data manipulation, cleaning, and exploratory analysis.
#
# You will work with a dataset of synthetic flood events (`flood_events.csv`).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#      event_id        date region  rainfall_mm  affected_population  \
# 0    EVT_0001  2023-08-17   East         37.0                  209
# 1    EVT_0002  2016-04-17  South         94.6                  978
# 2    EVT_0003  2012-06-13  North         88.5                  345
# 3    EVT_0004  2015-07-05   East        100.2                 1295
# 4    EVT_0005  2015-02-13   East         50.3                  289
# ..        ...         ...    ...          ...                  ...
# 115  EVT_0116  2018-11-29  South        140.1                  520
# 116  EVT_0117  2022-02-12   West         91.8                  747
# 117  EVT_0118  2010-10-18  South         25.9                  190
# 118  EVT_0119  2012-05-01  South        122.8                    1
# 119  EVT_0120  2017-07-22   West        102.9                  537
#
#      damage_usd   data_source
# 0     113430.80     satellite
# 1    1124402.06  local_survey
# 2     242873.33           gov
# 3    1197765.41     satellite
# 4     191933.33     satellite
# ..          ...           ...
# 115  1383856.45  local_survey
# 116  1218415.37           gov
# 117    25245.13           gov
# 118     1393.00           gov
# 119   543967.63  local_survey
#
# [120 rows x 7 columns]

# %% [markdown]
# ## Part 1: Data Loading & Inspection

# %%
# TODO: Inspect dataset
# Load dataset
df = pd.read_csv('flood_events.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             120 non-null    object
#  1   date                 120 non-null    object
#  2   region               120 non-null    object
#  3   rainfall_mm          115 non-null    float64
#  4   affected_population  120 non-null    int64
#  5   damage_usd           115 non-null    float64
#  6   data_source          120 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.7+ KB
#         event_id          date region  rainfall_mm  affected_population  \
# count        120           120    120   115.000000           120.000000
# unique       120           117      5          NaN                  NaN
# top     EVT_0001  invalid_date  South          NaN                  NaN
# freq           1             3     33          NaN                  NaN
# mean         NaN           NaN    NaN    83.482609           520.183333
# std          NaN           NaN    NaN    40.240091           290.395268
# min          NaN           NaN    NaN     1.400000             1.000000
# 25%          NaN           NaN    NaN    55.350000           319.750000
# 50%          NaN           NaN    NaN    85.600000           522.000000
# 75%          NaN           NaN    NaN   107.650000           710.000000
# max          NaN           NaN    NaN   194.000000          1295.000000
#
#           damage_usd   data_source
# count   1.150000e+02           120
# unique           NaN             3
# top              NaN  local_survey
# freq             NaN            42
# mean    5.258407e+05           NaN
# std     4.875668e+05           NaN
# min     4.903500e+02           NaN
# 25%     1.691540e+05           NaN
# 50%     3.838467e+05           NaN
# 75%     7.428108e+05           NaN
# max     2.369649e+06           NaN

# %% [markdown]
# ## Part 2: Data Cleaning
# - Convert date column
# - Handle missing values - explain choices
# - Fix data types if required
# - Remove duplicates

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             107 non-null    object
#  1   date                 107 non-null    datetime64[ns]
#  2   region               107 non-null    object
#  3   rainfall_mm          107 non-null    float64
#  4   affected_population  107 non-null    int64
#  5   damage_usd           107 non-null    float64
#  6   data_source          107 non-null    object
#  7   damage_per_person    107 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 7.5+ KB
#      event_id       date   region  rainfall_mm  affected_population  \
# 0    EVT_0001 2023-08-17     East         37.0                  209
# 1    EVT_0002 2016-04-17    South         94.6                  978
# 2    EVT_0003 2012-06-13    North         88.5                  345
# 3    EVT_0004 2015-07-05     East        100.2                 1295
# 4    EVT_0005 2015-02-13     East         50.3                  289
# 5    EVT_0006 2020-03-03     East         74.3                  390
# 6    EVT_0007 2023-05-01    North        117.5                  527
# 7    EVT_0008 2013-02-13     West         56.2                  373
# 8    EVT_0009 2017-06-26     West        153.3                   98
# 9    EVT_0010 2011-11-20    North        134.4                  743
# 10   EVT_0011 2015-11-15  Central        126.7                  352
# 11   EVT_0012 2021-04-17     East         24.9                  559
# 12   EVT_0013 2011-05-31  Central         94.9                  611
# 13   EVT_0014 2021-08-07    North         76.2                   86
# 14   EVT_0015 2010-04-09     West        122.3                  408
# 15   EVT_0016 2020-06-07    South         39.3                  384
# 16   EVT_0017 2010-12-01    North         98.8                  279
# 17   EVT_0018 2010-11-26    North         54.4                  317
# 18   EVT_0019 2021-07-30    South         59.4                  347
# 19   EVT_0020 2021-10-08     East         85.6                  482
# 20   EVT_0021 2013-01-27     West         41.6                  381
# 21   EVT_0022 2024-06-25     West         74.4                  509
# 22   EVT_0023 2023-07-29  Central         72.8                  585
# 23   EVT_0024 2023-10-27    South          6.8                  529
# 24   EVT_0025 2013-02-18    South        113.2                  874
# 26   EVT_0027 2017-02-19    North        136.2                  766
# 27   EVT_0028 2010-05-03    South         70.5                  681
# 28   EVT_0029 2014-01-11    South         63.4                    1
# 29   EVT_0030 2012-08-23     East         85.6                  741
# 30   EVT_0031 2024-01-28     West        109.6                  583
# 31   EVT_0032 2017-10-01  Central        171.1                  326
# 32   EVT_0033 2022-11-15    South          6.9                  784
# 33   EVT_0034 2020-09-21     East         86.5                  564
# 34   EVT_0035 2018-03-24    North         64.4                  961
# 35   EVT_0036 2014-06-26    North        161.3                  708
# 36   EVT_0037 2022-04-03     West         85.5                  679
# 38   EVT_0039 2012-09-11    North         70.4                  594
# 39   EVT_0040 2023-05-25     East        105.5                  377
# 40   EVT_0041 2024-04-30     West         55.0                  373
# 42   EVT_0043 2016-12-25    South         52.7                  762
# 43   EVT_0044 2023-11-20  Central         98.9                  217
# 44   EVT_0045 2019-03-05     East         54.7                  358
# 45   EVT_0046 2014-08-13     East         16.7                  875
# 47   EVT_0048 2012-05-02     East        103.2                  595
# 48   EVT_0049 2017-10-23     East         84.0                  944
# 49   EVT_0050 2015-11-09    North         68.9                  320
# 50   EVT_0051 2024-08-21     West         78.1                  375
# 51   EVT_0052 2017-01-08    North         97.3                  638
# 52   EVT_0053 2024-10-03     West        194.0                  432
# 53   EVT_0054 2013-02-12    North         97.4                  803
# 55   EVT_0056 2019-02-06    South         65.0                  130
# 56   EVT_0057 2024-08-27    North        167.4                  442
# 57   EVT_0058 2016-01-14     West         98.6                  280
# 58   EVT_0059 2011-08-24    North         73.3                  254
# 59   EVT_0060 2021-10-06    North         24.8                  122
# 61   EVT_0062 2011-06-20    North         44.2                  378
# 62   EVT_0063 2016-06-21     East        128.6                  250
# 63   EVT_0064 2022-06-17    South         44.9                  484
# 64   EVT_0065 2010-12-17     East        124.3                 1131
# 65   EVT_0066 2017-06-04    South         78.9                  600
# 66   EVT_0067 2013-10-15    North         33.3                    1
# 67   EVT_0068 2022-05-05  Central        122.2                  352
# 68   EVT_0069 2015-11-13     East         63.4                 1120
# 69   EVT_0070 2018-07-26    North         82.7                  299
# 70   EVT_0071 2023-05-10    South         55.7                 1196
# 71   EVT_0072 2018-02-18     West         14.9                  548
# 72   EVT_0073 2020-03-02     East         84.0                  308
# 74   EVT_0075 2023-10-10    North        103.9                  527
# 76   EVT_0077 2024-12-28  Central        112.3                    1
# 77   EVT_0078 2023-04-21    South        105.1                  287
# 78   EVT_0079 2010-12-09     West        104.2                  581
# 79   EVT_0080 2023-09-09     East        102.7                  396
# 80   EVT_0081 2021-11-19    South        107.0                   53
# 81   EVT_0082 2013-03-25    North         37.3                 1036
# 82   EVT_0083 2019-12-23    North         71.2                  493
# 83   EVT_0084 2011-11-02    North          1.4                 1096
# 84   EVT_0085 2015-07-01     West         78.5                  610
# 86   EVT_0087 2022-09-16  Central          9.2                   71
# 87   EVT_0088 2018-10-04  Central        113.1                  868
# 88   EVT_0089 2020-12-28    South         89.5                  168
# 89   EVT_0090 2021-02-26  Central        130.1                  568
# 91   EVT_0092 2022-01-13    South         36.7                  379
# 92   EVT_0093 2023-08-13    South         59.1                  797
# 93   EVT_0094 2023-08-09     East        108.3                  414
# 94   EVT_0095 2022-08-22  Central         28.0                  972
# 95   EVT_0096 2015-12-10    South        162.0                  611
# 96   EVT_0097 2012-01-06    North        117.4                  175
# 97   EVT_0098 2013-11-15    South        137.3                  998
# 99   EVT_0100 2017-12-23  Central         58.0                  810
# 101  EVT_0102 2021-11-30    South         45.3                  251
# 102  EVT_0103 2014-12-14    North         92.6                  411
# 103  EVT_0104 2019-02-27     West         96.4                  160
# 104  EVT_0105 2017-10-02    South         90.9                  435
# 105  EVT_0106 2021-03-18    South        103.4                  806
# 106  EVT_0107 2021-12-29     East         68.5                  589
# 107  EVT_0108 2014-11-17    South         48.4                  631
# 108  EVT_0109 2015-11-23  Central         34.6                  604
# 109  EVT_0110 2024-10-07     West         90.4                  697
# 110  EVT_0111 2019-07-10     West         89.0                  524
# 111  EVT_0112 2020-11-02  Central         95.7                  977
# 113  EVT_0114 2022-09-18  Central        135.2                  118
# 114  EVT_0115 2015-02-05    South        167.2                  581
# 115  EVT_0116 2018-11-29    South        140.1                  520
# 116  EVT_0117 2022-02-12     West         91.8                  747
# 117  EVT_0118 2010-10-18    South         25.9                  190
# 118  EVT_0119 2012-05-01    South        122.8                    1
# 119  EVT_0120 2017-07-22     West        102.9                  537
#
#      damage_usd   data_source  damage_per_person
# 0     113430.80     satellite         542.731100
# 1    1124402.06  local_survey        1149.695358
# 2     242873.33           gov         703.980667
# 3    1197765.41     satellite         924.915375
# 4     191933.33     satellite         664.129170
# 5     552515.62           gov        1416.706718
# 6     955691.45  local_survey        1813.456262
# 7     231541.84     satellite         620.755603
# 8     109298.20  local_survey        1115.287755
# 9     918683.68           gov        1236.451790
# 10    277036.79  local_survey         787.036335
# 11    107015.89  local_survey         191.441664
# 12    475173.61           gov         777.698216
# 13     53671.56     satellite         624.087907
# 14    593395.43     satellite        1454.400564
# 15     79250.16           gov         206.380625
# 16    488591.47     satellite        1751.223907
# 17    144024.74           gov         454.336719
# 18    129357.95  local_survey         372.789481
# 19    416632.77           gov         864.383340
# 20    141761.26  local_survey         372.076798
# 21    666252.72           gov        1308.944440
# 22    802086.30  local_survey        1371.087692
# 23     18324.26     satellite          34.639433
# 24   1769536.43  local_survey        2024.641224
# 26   1476823.20  local_survey        1927.967624
# 27    569035.71     satellite         835.588414
# 28       490.35     satellite         490.350000
# 29    913450.83           gov        1232.727166
# 30    996010.92     satellite        1708.423533
# 31    525456.45           gov        1611.829601
# 32     41729.45     satellite          53.226339
# 33    615698.23  local_survey        1091.663528
# 34    824672.80     satellite         858.140271
# 35   2207310.94     satellite        3117.670819
# 36    307443.19           gov         452.788203
# 38    318584.88     satellite         536.338182
# 39    762175.57     satellite        2021.685862
# 40    147423.29           gov         395.236702
# 42    206659.92     satellite         271.207244
# 43    200226.88  local_survey         922.704516
# 44    163660.43  local_survey         457.152039
# 45    106221.25           gov         121.395714
# 47    436308.99  local_survey         733.292420
# 48   1059425.60     satellite        1122.272881
# 49    373997.79           gov        1168.743094
# 50    272318.79  local_survey         726.183440
# 51    911221.75           gov        1428.247257
# 52    547163.55           gov        1266.582292
# 53    400787.94  local_survey         499.113250
# 55     89408.93  local_survey         687.761000
# 56    985883.68     satellite        2230.506063
# 57    466119.88     satellite        1664.713857
# 58    313541.90     satellite        1234.416929
# 59     52936.53  local_survey         433.905984
# 61    313117.46  local_survey         828.353069
# 62    532682.08  local_survey        2130.728320
# 63    343818.63  local_survey         710.369070
# 64   1734053.72           gov        1533.203996
# 65    593088.68     satellite         988.481133
# 66       511.61     satellite         511.610000
# 67    301087.16     satellite         855.361250
# 68    355689.12           gov         317.579571
# 69    208864.59           gov         698.543779
# 70    508191.15  local_survey         424.908988
# 71     65921.38     satellite         120.294489
# 72    380687.22  local_survey        1235.997468
# 74    585439.61     satellite        1110.891101
# 76      2106.14  local_survey        2106.140000
# 77    318254.18           gov        1108.899582
# 78    528229.82  local_survey         909.173528
# 79    423916.56  local_survey        1070.496364
# 80    107725.05     satellite        2032.548113
# 81    739625.73           gov         713.924450
# 82    431040.46           gov         874.321420
# 83     25151.48           gov          22.948431
# 84    766828.53     satellite        1257.095951
# 86     10945.16     satellite         154.157183
# 87   1127188.11     satellite        1298.603813
# 88    201379.34     satellite        1198.686548
# 89    854353.77           gov        1504.143961
# 91    256803.33           gov         677.581346
# 92    298181.26           gov         374.129561
# 93    506587.03     satellite        1223.640169
# 94    208209.04  local_survey         214.206831
# 95   1838200.59           gov        3008.511604
# 96    174647.52     satellite         997.985829
# 97   1965117.89  local_survey        1969.056002
# 99    296727.53     satellite         366.330284
# 101    70048.61     satellite         279.078127
# 102   580813.74  local_survey        1413.172117
# 103   118525.61           gov         740.785062
# 104   688889.51  local_survey        1583.654046
# 105   561937.61  local_survey         697.193065
# 106   383846.73     satellite         651.692241
# 107   361874.96           gov         573.494390
# 108   331264.26  local_survey         548.450762
# 109   745995.95           gov        1070.295481
# 110   387826.14  local_survey         740.126221
# 111   642890.57           gov         658.025148
# 113   293485.75  local_survey        2487.167373
# 114  1172078.20  local_survey        2017.346299
# 115  1383856.45  local_survey        2661.262404
# 116  1218415.37           gov        1631.078139
# 117    25245.13           gov         132.869105
# 118     1393.00           gov        1393.000000
# 119   543967.63  local_survey        1012.975102

# %% [markdown]
# ## Part 3: Basic Analysis

# %% [markdown]
# - Compute total number of events per region
# - Compute mean and median rainfall per region
# - Find the top 3 regions by total 'damage_usd'
# - Calculate the correlation between 'rainfall_mm' and 'damage_usd'

# %%
# Out:
# Total number of events per region:
# region
# South      33
# North      27
# East       24
# West       19
# Central    17
# Name: count, dtype: int64
# Mean rainfall per region:
# region
# Central    94.647059
# East       75.968182
# North      86.026923
# South      75.703226
# West       91.405263
# Name: rainfall_mm, dtype: float64
# Median rainfall per region:
# region
# Central    98.9
# East       84.0
# North      85.6
# South      65.0
# West       90.4
# Name: rainfall_mm, dtype: float64
# Top 3 regions by total damage (USD):
# region
# South    16968648.26
# North    14918825.61
# East     13381525.05
# Name: damage_usd, dtype: float64
# Correlation between rainfall (mm) and damage (USD):
# np.float64(0.5919002959097437)

# %% [markdown]
# ## Part 4: Derived Insights

# %% [markdown]
# Compute derived columns and insights
# 1. Create a new column `damage_per_person = damage_usd / affected_population`.
# 2. Identify the top 5 events by `damage_per_person`.
# 3. For each `data_source`, calculate average `rainfall_mm` and total `damage_usd`.

# %%
# Out:
# Top 5 events by damage per person:
#      event_id       date   region  rainfall_mm  affected_population  \
# 35   EVT_0036 2014-06-26    North        161.3                  708
# 95   EVT_0096 2015-12-10    South        162.0                  611
# 115  EVT_0116 2018-11-29    South        140.1                  520
# 113  EVT_0114 2022-09-18  Central        135.2                  118
# 60   EVT_0061 2015-11-15     East          NaN                  955
#
#      damage_usd   data_source  damage_per_person
# 35   2207310.94     satellite        3117.670819
# 95   1838200.59           gov        3008.511604
# 115  1383856.45  local_survey        2661.262404
# 113   293485.75  local_survey        2487.167373
# 60   2369649.46  local_survey        2481.308335
# Average rainfall per data source:
# data_source
# gov             80.876316
# local_survey    90.352500
# satellite       78.732432
# Name: rainfall_mm, dtype: float64
# Total damage per data source:
# data_source
# gov             18776909.71
# local_survey    24862498.48
# satellite       16832267.75
# Name: damage_usd, dtype: float64

# %% [markdown]
# ## Part 5: Visualization

# %% [markdown]
# Create the following visualisations
#
# - Bar chart of total damage by region.
# - Scatter plot of rainfall vs. damage.
