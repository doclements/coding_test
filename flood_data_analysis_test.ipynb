# %% [markdown]
# # Flood Events Data Analysis Test
# This notebook is a technical assessment designed to evaluate your skills in pandas-based data manipulation, cleaning, and exploratory analysis.
#
# You will work with a dataset of synthetic flood events (`flood_events.csv`).
#
# **You are encouraged to use all available resources during the test, and may use the internet, google, API documentation etc**.
#
# You must use the existing imported libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part 1: Data Loading & Inspection
#
# In this part can you load the data and show what techniques you have for basic investigation of the data. e.g. what are teh data types, how many rows, how many null values, etc

# %%
# TODO: Inspect dataset
# Load dataset
df = pd.read_csv('flood_events.csv')

# %% [markdown]
# ## Part 2: Data Cleaning
# Once we have done some basic investigation of the data we will often have to clean it up, below are some tasks to do to make teh data example more useful, walk me through what mechanisms there are to achieve the following and carry them out on the dataframe
#
# - Convert date column to datetime type
# - Handle any missing values - explain choices
# - Remove duplicates

# %% [markdown]
# ## Part 3: Basic Analysis

# %% [markdown]
# - Compute and display the total number of events per region
# - Compute and display the mean and median rainfall per region
# - Find and display the top 3 regions by total 'damage_usd'
# - Calculate and display whether there is a correlation between 'rainfall_mm' and 'damage_usd'

# %% [markdown]
# ## Part 4: Derived Insights

# %% [markdown]
# As well as basic analysis we can create derived information from the source data. For this task compute a derived column and display some insights
# 1. Create a new column `damage_per_person`. (think about what data we have and what data would be used to calculate the required column)
# 2. Identify and display the top 5 events by `damage_per_person`.
# 3. For each `data_source`, calculate and display the mean `rainfall_mm` and total `damage_usd`.

# %% [markdown]
# ## Part 5: Visualization

# %% [markdown]
# Once we have process and created some insight from source data we often will have to create visualisations so that we can communicate what we have learned. Create the following visualisations from teh data we have available. We will use the seaborn library for this.
#
# - Bar chart of total damage by region.
# - Scatter plot of rainfall vs. damage.
