# %% [markdown]
# # 🧮 Flood Events Data Analysis Test
# This notebook is a technical assessment designed to evaluate your skills in pandas-based data manipulation, cleaning, and exploratory analysis.
#
# You will work with a dataset of synthetic flood events (`flood_events.csv`).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('flood_events.csv')
df.head()

# %% [markdown]
# ## Part 1: Data Loading & Inspection

# %%
# TODO: Inspect dataset
df.info()
df.describe(include='all')

# %% [markdown]
# ## Part 2: Data Cleaning
# - Convert date column
# - Handle missing values
# - Fix data types
# - Remove duplicates

# %%
# TODO: Perform data cleaning steps

# %% [markdown]
# ## Part 3: Basic Analysis

# %%
# TODO: Compute total number of events per region, etc.

# %% [markdown]
# ## Part 4: Derived Insights

# %%
# TODO: Compute derived columns and insights

# %% [markdown]
# ## Part 5: Visualization

# %%
# TODO: Create at least one plot
# Example: Total damage by region
sns.barplot(data=df, x='region', y='damage_usd', estimator=sum)
plt.title('Total Damage by Region')
plt.show()

# %% [markdown]
# ## Part 6: Reporting
# Summarize your key findings below:

# %%
Write a short summary here in Markdown or as text comments.
